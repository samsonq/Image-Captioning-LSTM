# %%
import numpy as np
import torch
import torch.nn as nn
from torchvision.models import resnet50
import pkbar
from tqdm import tqdm
import json
import dataset_factory
from experiment import Experiment
import coco_dataset
import vocab
import warnings
warnings.filterwarnings("ignore")
# import nltk
# nltk.download('punkt')
# Out:
# Using CUDA
# Using CUDA

# %%
f = open("./embedhidden1.json")

config = json.load(f)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
exp_name = 'embedhidden1'

print("Running Experiment: ", exp_name)
exp = Experiment(exp_name)
exp.run()
exp.test()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a3a0a892f0d8> in <module>
# ----> 1 f = open("./embedhidden1.json")
#       2
#       3 config = json.load(f)
#       4
#       5 device = 'cuda' if torch.cuda.is_available() else 'cpu'
#
# FileNotFoundError: [Errno 2] No such file or directory: './embedhidden1.json'

# %%
f = open("./embedhidden2.json")

config = json.load(f)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
exp_name = 'embedhidden2'

print("Running Experiment: ", exp_name)
exp = Experiment(exp_name)
exp.run()
exp.test()
# Out:
# cuda
# Running Experiment:  embedhidden2
# loading annotations into memory...
# Done (t=0.76s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.33s)
# creating index...
# index created!
# Using the saved vocab.
# loading annotations into memory...
# Done (t=0.74s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.69s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.31s)
# creating index...
# index created!
# Epoch: 1, Train Loss: 2.7136443655889946, Val Loss: 2.1625369539627664, Took 0:07:25.737533, ETA: 1:06:51.637797
# Epoch: 2, Train Loss: 2.0348337184717726, Val Loss: 1.9301092239526603, Took 0:07:29.736347, ETA: 0:59:57.890776
# Epoch: 3, Train Loss: 1.8024394787432299, Val Loss: 1.7855161066238696, Took 0:07:29.177638, ETA: 0:52:24.243466
# Epoch: 4, Train Loss: 1.6565894077264187, Val Loss: 1.6825570363264817, Took 0:07:21.756147, ETA: 0:44:10.536882
# ...

# %%
# f = open("./model_configs/embedhidden3.json")

# config = json.load(f)
# config
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
exp_name = 'embedhidden3'

print("Running Experiment: ", exp_name)
exp = Experiment(exp_name)
exp.run()
exp.test()
# Out:
# cuda
# Running Experiment:  embedhidden3
# ./model_configs/embedhidden3.json
# loading annotations into memory...
# Done (t=0.70s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.33s)
# creating index...
# index created!
# Using the saved vocab.
# loading annotations into memory...
# Done (t=0.68s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.70s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.36s)
# creating index...
# index created!
# ./experiment_data/embedhidden3/training_losses.txt
# ./experiment_data/embedhidden3/val_losses.txt
#   0%|          | 1/235 [00:02<08:57,  2.30s/it]
# predicted caption: a cat is laying on a bed with a blanket
# actual caption: a large dog laying on the floor next to a couch and a dark colored cat laying on the floor to the side of the dog
#   1%|          | 2/235 [00:03<07:08,  1.84s/it]
# ...

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
exp_name = 'embedhiddendef'

print("Running Experiment: ", exp_name)
exp = Experiment(exp_name)
exp.run()
exp.test()
# Out:
# cuda
# Running Experiment:  embedhiddendef
# loading annotations into memory...
# Done (t=0.63s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.36s)
# creating index...
# index created!
# Using the saved vocab.
# loading annotations into memory...
# Done (t=0.68s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.66s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.29s)
# creating index...
# index created!
#   1%|          | 2/235 [00:01<04:18,  1.11s/it]
# sample predicted caption: a living room with a couch , couch , and a television .
# sample actual caption: a view of a tv and a statue laying on the ground , next to a window .
# sample predicted caption: a cat is sitting on a table with a book .
# sample actual caption: a grey and white cat is on a table and stands between a white storage container full of stuff and scissors .
# ...

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
exp_name = 'embedhiddendef'

print("Running Experiment: ", exp_name)
exp = Experiment(exp_name)
exp.run()
exp.test()
# Out:
# cuda
# Running Experiment:  embedhiddendef
# loading annotations into memory...
# Done (t=0.69s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.29s)
# creating index...
# index created!
# Using the saved vocab.
# loading annotations into memory...
# Done (t=0.60s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.74s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.30s)
# creating index...
# index created!
#   0%|          | 1/235 [00:02<08:38,  2.22s/it]
# sample predicted caption: a stop sign is on a pole near a street sign .
# sample actual caption: an upside down road sign showing three different `` only '' options on where your lane will take you .
#   1%|          | 2/235 [00:03<07:02,  1.81s/it]
# sample predicted caption: a dog is jumping up to a frisbee .
# sample actual caption: a small black dog standing next to a larger black dog on a red leash .
# ...

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
exp_name = 'embedhiddendef'

print("Running Experiment: ", exp_name)
exp = Experiment(exp_name)
exp.run()
exp.test()
# Out:
# cuda
# Running Experiment:  embedhiddendef
# loading annotations into memory...
# Done (t=0.59s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.29s)
# creating index...
# index created!
# Using the saved vocab.
# loading annotations into memory...
# Done (t=0.61s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.59s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.30s)
# creating index...
# index created!
#   0%|          | 1/235 [00:01<07:18,  1.88s/it]
# sample predicted caption: a stop sign with a street sign on it
# sample actual caption: a pole with a stop sign on it , plus a street sign for w. <unk> street .
#   1%|          | 2/235 [00:02<06:22,  1.64s/it]
# sample predicted caption: a woman in a hat is standing on a skateboard
# sample actual caption: two men have stopped in a field while one of them in a white shirt fixes the other man 's tie .
# ...

# %%
a = torch.tensor([[24, -3, -2], [23, -3, -2]]).to('cuda')
a
# Out:
# tensor([[24, -3, -2],
#         [23, -3, -2]], device='cuda:0')

# %%
p = torch.tensor([[.33, .33, .33], [.5, .25, .25]]).to('cuda')
p
# Out:
# tensor([[0.3300, 0.3300, 0.3300],
#         [0.5000, 0.2500, 0.2500]], device='cuda:0')

# %%
p
# Out:
# tensor([[0.3300, 0.3300, 0.3300],
#         [0.5000, 0.2500, 0.2500]], device='cuda:0')

# %%
c = p.cumsum(axis=1).double()
c
# Out:
# tensor([[0.3300, 0.6600, 0.9900],
#         [0.5000, 0.7500, 1.0000]], device='cuda:0', dtype=torch.float64)

# %%
u = np.random.rand(len(c), 1)
u
# Out:
# array([[0.97469825],
#        [0.90948197]])

# %%
choices = (torch.from_numpy(u).to('cuda').double() < c).argmax(axis=1)
choices
# Out:
# tensor([2, 2], device='cuda:0')

# %%
a.gather(1, choices.view(-1, 1))
# Out:
# tensor([[-2],
#         [23]], device='cuda:0')

# %%
a = (torch.tensor([[2,2,2], [4,4,4]])).to(device)
a
# Out:
# tensor([[2, 2, 2],
#         [4, 4, 4]], device='cuda:0')

# %%
for p in torch.exp(a.float())/torch.sum(torch.exp(a.float()), axis = 1).view(-1, 1):
    print(np.random.choice(np.arange(p.shape[0]), p = p.cpu().numpy()))
# Out:
# 1
# 1

# %%
a - torch.max(a, axis = 1).values.view(-1, 1)
# Out:
# tensor([[0, 0, 0],
#         [0, 0, 0]], device='cuda:0')
